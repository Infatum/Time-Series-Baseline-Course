# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
data = pd.read_csv('supermarket_sales - Sheet.csv')

# %% [markdown]
# ### Обзор датасета

# %%
data.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# Датафреймы — это таблицы. У их есть строки, колонки и ячейки.
#
# Технически, колонки датафреймов — это серии. Поскольку в колонках обычно описывают одни и те же объекты, то все колонки делят один и тот же индекс.

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ### Задача 1.1
#
# Установить индекс по Invoice ID и определить размер датафрейма. Результат на проверку: ![image.png](attachment:image.png)

# %% [markdown]
# ### Задача 1.2
# Определить статистику продаж по колонке "Total". Результат на проверку: ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Задача 1.3
# Определить статистику продаж по колонке "gross income". Результат на проверку: ![image.png](attachment:image.png)

# %% [markdown]
# ### Задача 2.1
# Выбрать по ID '123-19-1176', '303-96-2227'. Результат должен был получится: ![image.png](attachment:image.png)
# А также выбирете первый, третий и пятый элементы. Результат на проверку: ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Задача 2.2
# Узнать, откуда приходят самые большие заказы, определить все покупки стоимостью более 1000 долларов и также сколько из этих покупок было сделано женщинами. Вы должны получить такой ответ: ![image.png](attachment:image.png)

# %% [markdown]
# ### Задача 3
# Определить сколько всего было оплачено каким видом платежа по колонке "Payment". Правильный ответ: ![image-2.png](attachment:image-2.png) и сколько какого вида товара по "Product line". Правильный ответ: ![image-3.png](attachment:image-3.png) А также средний чек покупки. Правильный ответ: 322.966749

# %% [markdown]
# ### Задача 4
#  Определим метку времени, соединив 2 колонки 'Date' и 'Time' и установим временной индекс. Помни, даты прочитанные из csv имеют строковое представление, поэтому после получения строки с датой и временем их нужно перевести в pandas.Timestamp с помощью функции pandas.to_datetime(). Колонки Date и Time можно удалить. Проверка результата: ![image.png](attachment:image.png) Проверка индекса получившегося Датафрейма: ![image-2.png](attachment:image-2.png)

# %%
data['datetime'] = data['Date'] + ' ' +  data['Time']
data['datetime'] = pd.to_datetime(data.datetime)

# %%
data_df = data.set_index('datetime')
data_df = data_df.drop(columns=['Date', 'Time'], axis=1)

# %% [markdown]
# ### Задача 5.1
# Посчитать выручку за каждую неделю и за каждый месяц по городам. Недельный результат: ![image-3.png](attachment:image-3.png)
# ### Задача 5.2
# Месячный результат: ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Задача 6.1
# Построить гистограмму ежедневной средней прибыли "gross income" и посмотреть ее распределение. Результат для сверки: ![image.png](attachment:image.png)
#
# ### Задача 6.2
# Построить график еженедельных суммарных продаж в городе Mandalay. Правильный результат: ![image-2.png](attachment:image-2.png)
